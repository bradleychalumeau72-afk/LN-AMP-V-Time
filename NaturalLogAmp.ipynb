# %%
import numpy
import matplotlib.pyplot
import math

# %%
time, natural_log = numpy.loadtxt('amplitude natural log - Sheet1.csv', delimiter=',', skiprows=25, unpack=True)

# %%
matplotlib.pyplot.plot(time, numpy.log(natural_log))
matplotlib.pyplot.show()
# Out:
# /var/folders/dl/bbcqdlpj0cl4646m8vfdfj3m0000gn/T/ipykernel_69146/3686886477.py:1: RuntimeWarning: divide by zero encountered in log
#   matplotlib.pyplot.plot(numpy.log(natural_log), time)
# /var/folders/dl/bbcqdlpj0cl4646m8vfdfj3m0000gn/T/ipykernel_69146/3686886477.py:1: RuntimeWarning: invalid value encountered in log
#   matplotlib.pyplot.plot(numpy.log(natural_log), time)
